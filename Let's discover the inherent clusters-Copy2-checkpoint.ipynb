# %% [markdown]
# # Let's discover the inherent clusters

# %% [markdown]
# ### Importing our data set

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('CC GENERAL.csv')
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.drop(axis=1,columns="CUST_ID",inplace=True)

# %%
df.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df["MINIMUM_PAYMENTS"].fillna(df['MINIMUM_PAYMENTS'].mean(),inplace=True)
df["CREDIT_LIMIT"].fillna(df['CREDIT_LIMIT'].mean(),inplace=True)

# %% [markdown]
# # Hierarchical Clustering

# %%
from sklearn.cluster import AgglomerativeClustering
model = AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='ward')
clf=model.fit_predict(df)
clf_pred = pd.DataFrame(clf)
clf_pred.head()
# Out:
#    0
# 0  3
# 1  1
# 2  1
# 3  1
# 4  3

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
scatter = ax.scatter(df['PURCHASES'],df['BALANCE'],c=clf_pred[0],s=50)
ax.set_title('Agglomerative Clustering')
plt.colorbar(scatter);

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10,7))
plt.title('Customer Dendograms')
dend = shc.dendrogram(shc.linkage(df,method='complete'))

# %% [markdown]
# # K-Means

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(n_clusters=5,random_state=0)
kmeans.fit(df);
kmeans.predict(df);

# %%
labels=pd.DataFrame(kmeans.labels_)
labels.head()
# Out:
#    0
# 0  0
# 1  4
# 2  4
# 3  4
# 4  0

# %%
KMeanModel=KMeans()
from scipy.spatial.distance import cdist
distortions = []
for k in range(1,10):
    KMeanModel = KMeans(n_clusters=k)
    KMeanModel.fit(df)
    distortions.append(sum(np.min(cdist(df, KMeanModel.cluster_centers_, 'euclidean'), axis=1)) / df.shape[0])

plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method ')
plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
scatter = ax.scatter(df['PURCHASES_TRX'],df['PURCHASES'],c=clf_pred[0],s=50)
ax.set_title('Agglomerative Clustering')
plt.colorbar(scatter);

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
scatter = ax.scatter(df['PURCHASES_TRX'],df['PURCHASES'],c=labels[0],s=50)
ax.set_title('K-Means Clustering')
plt.colorbar(scatter);

# %% [markdown]
# We can see that the two models are quite the same except for some few differences
